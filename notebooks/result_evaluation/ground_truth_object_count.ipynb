# %%
import sys
sys.path.append('../../scripts')
import numpy as np
import cv2 
from PIL import Image
from utils import *
import os

# %% [markdown]
# Obtaining all of the ground truth images

# %%
DATASET_FOLDER= f'../../data/cells_dataset/labels/'
gt_imgs = [(image_name, cv2.imread(f'{DATASET_FOLDER}/{image_name}', cv2.IMREAD_GRAYSCALE)) for image_name in os.listdir(DATASET_FOLDER)]
visualize(image1 = gt_imgs[1][1], image2 = gt_imgs[2][1])

# %%
amount_of_obj = [(gt_tuple[0], (cv2.connectedComponents(gt_tuple[1])[0])) for gt_tuple in gt_imgs]
amount_of_obj
# Out:
# [('5.png', 48),
#  ('6.png', 85),
#  ('3.png', 117),
#  ('1.png', 140),
#  ('8.png', 44),
#  ('10.png', 17),
#  ('7.png', 95),
#  ('2.png', 158),
#  ('9.png', 16),
#  ('4.png', 95)]

# %%
num_objetos, rotulos = cv2.connectedComponents(gt)
print(num_objetos)
# Out:
# 117

# %%
gt.shape, segmentation.shape
# Out:
# ((1532, 2048), (1532, 2048))
